# %%
import fasttext
from scipy.stats import spearmanr
from gensim.models import FastText

# %%
model = FastText.load_fasttext_format('wiki-news-300d-1M.vec')
# Out:
# C:\Users\aygul\AppData\Local\Temp\ipykernel_13928\799414732.py:1: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   model = FastText.load_fasttext_format('wiki-news-300d-1M.vec')
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = FastText.load_fasttext_format('wiki-news-300d-1M.vec')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\utils.py:1522, in deprecated.<locals>.decorator.<locals>.new_func1(*args, **kwargs)
#    1515 @wraps(func)
#    1516 def new_func1(*args, **kwargs):
#    1517     warnings.warn(
#    1518         fmt.format(name=func.__name__, reason=reason),
#    1519         category=DeprecationWarning,
#    1520         stacklevel=2
#    1521     )
# -> 1522     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\fasttext.py:580, in FastText.load_fasttext_format(cls, model_file, encoding)
#     568 @classmethod
#     569 @utils.deprecated(
#     570     'use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model '
#     571     '(to continue training with the loaded full model, more RAM) instead'
#     572 )
#     573 def load_fasttext_format(cls, model_file, encoding='utf8'):
#     574     """Deprecated.
#     575
#     576     Use :func:`gensim.models.fasttext.load_facebook_model` or
#     577     :func:`gensim.models.fasttext.load_facebook_vectors` instead.
#     578
#     579     """
# --> 580     return load_facebook_model(model_file, encoding=encoding)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\fasttext.py:728, in load_facebook_model(path, encoding)
#     666 def load_facebook_model(path, encoding='utf-8'):
#     667     """Load the model from Facebook's native fasttext `.bin` output file.
#     668
#     669     Notes
#    (...)
#     726
#     727     """
# --> 728     return _load_fasttext_format(path, encoding=encoding, full_model=True)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\fasttext.py:808, in _load_fasttext_format(model_file, encoding, full_model)
#     789 """Load the input-hidden weight matrix from Facebook's native fasttext `.bin` output files.
#     790
#     791 Parameters
#    (...)
#     805
#     806 """
#     807 with utils.open(model_file, 'rb') as fin:
# --> 808     m = gensim.models._fasttext_bin.load(fin, encoding=encoding, full_model=full_model)
#     810 model = FastText(
#     811     vector_size=m.dim,
#     812     window=m.ws,
#    (...)
#     821     max_n=m.maxn,
#     822 )
#     823 model.corpus_total_words = m.ntokens
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\_fasttext_bin.py:345, in load(fin, encoding, full_model)
#     342 if not new_format:
#     343     model.update(dim=magic, ws=version)
# --> 345 raw_vocab, vocab_size, nwords, ntokens = _load_vocab(fin, new_format, encoding=encoding)
#     346 model.update(raw_vocab=raw_vocab, vocab_size=vocab_size, nwords=nwords, ntokens=ntokens)
#     348 vectors_ngrams = _load_matrix(fin, new_format=new_format)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gensim\models\_fasttext_bin.py:198, in _load_vocab(fin, new_format, encoding)
#     196 # Vocab stored by [Dictionary::save](https://github.com/facebookresearch/fastText/blob/master/src/dictionary.cc)
#     197 if nlabels > 0:
# --> 198     raise NotImplementedError("Supervised fastText models are not supported")
#     199 logger.info("loading %s words for fastText model from %s", vocab_size, fin.name)
#     201 ntokens = _struct_unpack(fin, '@q')[0]  # number of tokens
#
# NotImplementedError: Supervised fastText models are not supported

# %%
def load_goldstandard(file_name):
    goldstandard = {}
    with open(file_name, 'r') as file:
        for line in file:
            word1, word2, score = line.strip().split('\t')
            goldstandard[(word1, word2)] = float(score)
    return goldstandard

# %%
def calc_similarity(word1, word2):
    similarity = 0
    if word1 in model.index_to_key and word2 in model.index_to_key:
            similarity = model.similarity(word1, word2)
    return similarity

# %%
def spearman(values1, values2):
    spearman_correlation, _ = spearmanr(values1, values2)
    return spearman_correlation

# %%
def get_values(similarities):
    return [value for (word1, word2), value in similarities.items()]

# %%
def get_results(goldstandard_file_name):
    similarities = {}
    goldstandard = load_goldstandard(goldstandard_file_name)
    for (word1, word2), score in goldstandard.items():
        similarities[(word1, word2)] = calc_similarity(word1, word2)
    #print(similarities)
    goldstandard_values = list(goldstandard.values())
    print(spearman(get_values(similarities), goldstandard_values))

# %%
print("Spearman corellation for wordsim_similarity_goldstandard.txt:")
get_results(r'C:\Users\aygul\Desktop\NLP\wordsim353_sim_rel\wordsim_similarity_goldstandard.txt')
print("Spearman corellation for wordsim_relatedness_goldstandard.txt:")
get_results(r'C:\Users\aygul\Desktop\NLP\wordsim353_sim_rel\wordsim_relatedness_goldstandard.txt')
# Out:
# Spearman corellation for wordsim_similarity_goldstandard.txt:
# 0.8117711534936849
# Spearman corellation for wordsim_relatedness_goldstandard.txt:
# 0.6818611048832751
