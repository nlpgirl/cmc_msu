# %% [markdown]
# # Задание 13: модели E5 и LaBSE

# %%
# !pip install -U sentence-transformers transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers in /home/aigul/myenv/lib/python3.11/site-packages (4.57.3)
# Requirement already satisfied: tqdm in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/aigul/myenv/lib/python3.11/site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/aigul/myenv/lib/python3.11/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/aigul/myenv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/aigul/myenv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6)
# Requirement already satisfied: jinja2 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/aigul/myenv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aigul/myenv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aigul/myenv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aigul/myenv/lib/python3.11/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/aigul/myenv/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aigul/myenv/lib/python3.11/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aigul/myenv/lib/python3.11/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in /home/aigul/myenv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/aigul/myenv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.1.2

# %%
import re
import math
import numpy as np
from collections import Counter, defaultdict
import pymorphy3
import sentencepiece as spm
import os

# %%
from razdel import sentenize

with open("corpus.txt", "r", encoding="utf-8") as f:
    corpus_text = f.read().strip()

corpus_texts = [s.text for s in sentenize(corpus_text)]

# %%
CORPUS_SIZE = len(corpus_texts)

# %% [markdown]
# Заведем матрицу релевантностей rel_q и оценим каждое предложения для всех запросов

# %%
rel_q = 3 * [[0] * CORPUS_SIZE]

# %%
rel_q[0][0] = 2
rel_q[0][1] = 1
rel_q[0][2] = 2
rel_q[0][3] = 1

# %%
rel_q[1][73] = 1
rel_q[1][74] = 1
rel_q[1][75] = 2

# %%
rel_q[2][185] = 2
rel_q[2][186] = 2
rel_q[2][187] = 1
rel_q[2][188] = 1
rel_q[2][189] = 1
rel_q[2][191] = 1
rel_q[2][192] = 1
rel_q[2][196] = 1
rel_q[2][198] = 1
rel_q[2][200] = 1
rel_q[2][201] = 1
rel_q[2][204] = 1
rel_q[2][206] = 1
rel_q[2][211] = 1
rel_q[2][213] = 1
rel_q[2][225] = 1
rel_q[2][226] = 1
rel_q[2][229] = 1
rel_q[2][236] = 1
rel_q[2][237] = 1
rel_q[2][221] = 1
rel_q[2][230] = 1
rel_q[2][231] = 1
rel_q[2][232] = 2
rel_q[2][233] = 2
rel_q[2][300] = 1

# %%
import numpy as np
rel_q_sorted = np.sort(rel_q, axis=1)[:, ::-1]

# %%
from sentence_transformers import SentenceTransformer

models = {
    "e5-small": SentenceTransformer("intfloat/multilingual-e5-small"),
    "e5-large": SentenceTransformer("intfloat/multilingual-e5-large"),
    "labse": SentenceTransformer("sentence-transformers/LaBSE")
}
